# %%
import requests
from bs4 import BeautifulSoup

raw = requests.get("https://www.dhnews.co.kr/news/articleView.html?idxno=127188",
                  headers={'User-Agent': 'Mozilla/5.0'})
html = BeautifulSoup(raw.text, "html.parser")
html
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" dir="ltr" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=1080" name="viewport"/>
# <meta content="대학저널" name="apple-mobile-web-app-title">
# <meta content="대학저널, 명문대학길잡이, 대학과 수험생을 잇는 1등신문 , 수능공부법, 대학정보, 월간대학저널, 교육관련사이트, 대학뉴스, 교수초빙, 연구원초빙, 행정직원모집" name="keywords"/>
# <!-- 메타태그정보 //-->
# <meta content="4년 후...지방대 26곳은 신입생 절반도 못 채워" name="title">
# <meta content="[대학저널 이승환 기자] 지방대학 위기의 가장 큰 원인은 단연 학령인구 감소다. 만 18세 학령인구는 2020년 51만 명에서 2024년 43만 명으로 8만 명가량 준다.자연 신입생 모집에 어려움을 겪는 대학이 매년 크게 늘 수밖에 없다. 직격탄은 지방대학이 가장 먼저, 크게 맞는다.지방대학에 대한 사회적 차별과 편견이 여전함에 따라 지방대 학생 수는 매년 줄고 있다.2019년 지방대학 경쟁률은 7대 1로 수도권(13.6대 1) 절반 수준이다. 이는 대학 재정에 곧바로 영향을 준다. 2018년 기준 지방대학의 학생 1인당 재정 규모" name="description">
# <meta content="대학뉴스 &gt; 대학일반 &gt; 뉴스플러스" name="Classification">
# <meta content="대학저널" name="Copyright"/>
# <meta content="대학저널" property="og:site_name"/>
# ...
