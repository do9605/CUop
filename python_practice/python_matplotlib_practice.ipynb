# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %%
plt.plot([1, 2, 3, 4], [4, 10, 18, 28], 'bo')
plt.axis([0, 5, 0, 30])
plt.draw()

# %%
t = np.arange(0, 5, 0.2)

plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()
